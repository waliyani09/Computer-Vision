# %% [markdown]
# # CODE TO CONVERT COLOR IMAGES TO GRAYSCALE

# %% [markdown]
# # Import all the necessary libraries

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %% [markdown]
# # Read/Display an image

# %%
image_color = mpimg.imread('image_lane_c.jpg')

# %%
plt.imshow(image_color)

# %%
image_color.shape
# Out:
# (540, 960, 3)

# %% [markdown]
# # Convert an image into Grayscale

# %%
image_gray = cv2.cvtColor(image_color, cv2.COLOR_RGB2GRAY) #Corrected... image is RGB, not BGR.
plt.imshow(image_gray, cmap = 'gray')

# %%
image_gray.shape
# Out:
# (540, 960)

# %%
image_gray #This will give me the value of the pixels
# Out:
# array([[171, 171, 172, ..., 171, 171, 171],
#        [171, 171, 171, ..., 171, 171, 171],
#        [171, 171, 171, ..., 171, 171, 171],
#        ...,
#        [161, 163, 160, ..., 190, 191, 191],
#        [169, 167, 159, ..., 185, 186, 187],
#        [163, 155, 144, ..., 172, 173, 173]], dtype=uint8)

# %%
import sys
np.set_printoptions(threshold=sys.maxsize)
image_gray
# Out:
# array([[171, 171, 172, 171, 170, 170, 171, 172, 171, 171, 171, 171, 171,
#         171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171,
#         171, 171, 171, 171, 171, 171, 170, 170, 170, 170, 170, 170, 170,
#         170, 169, 169, 169, 169, 169, 169, 169, 169, 169, 169, 169, 169,
#         169, 169, 169, 169, 169, 169, 169, 169, 169, 169, 169, 169, 169,
#         169, 169, 169, 169, 169, 169, 169, 170, 170, 170, 170, 170, 170,
#         170, 170, 169, 169, 169, 169, 169, 169, 169, 168, 168, 168, 168,
#         168, 168, 168, 168, 168, 168, 168, 168, 169, 169, 169, 169, 169,
#         169, 169, 169, 169, 169, 169, 169, 169, 169, 169, 169, 169, 169,
#         169, 169, 169, 169, 169, 169, 169, 169, 169, 169, 169, 170, 170,
#         170, 170, 170, 170, 170, 170, 169, 169, 169, 169, 169, 169, 169,
#         169, 169, 169, 169, 169, 169, 169, 169, 169, 169, 169, 169, 169,
#         169, 169, 169, 169, 169, 169, 169, 169, 169, 169, 169, 169, 169,
# ...

# %% [markdown]
# # Save the Grayscale image

# %%
# Save the image in greyscale
cv2.imwrite("image_lane_g.jpg", image_gray)
# Out:
# True

# %% [markdown]
# # Well done!

# %%
plt.imshow(image_gray)
